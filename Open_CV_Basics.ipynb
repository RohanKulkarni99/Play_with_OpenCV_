# %% [markdown]
# # Learn Basic concepts of OPEN_CV like fliping, Rotating image and RGB

# %% [markdown]
# # Author- Rohan Kulkarni

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
taj=cv2.imread(r'E:\Imarticus\16.OPEN_CV\taj.jpg')

# %%
taj
# Out:
# array([[[242, 205, 185],
#         [242, 205, 185],
#         [242, 205, 185],
#         ...,
#         [171, 146, 130],
#         [171, 146, 130],
#         [171, 146, 130]],
#
#        [[242, 205, 185],
#         [242, 205, 185],
#         [242, 205, 185],
#         ...,
#         [173, 148, 132],
#         [173, 148, 132],
#         [173, 148, 132]],
#
#        [[242, 205, 185],
#         [242, 205, 185],
#         [242, 205, 185],
#         ...,
#         [172, 146, 130],
#         [172, 146, 130],
#         [172, 146, 130]],
#
#        ...,
#
#        [[  0,  13,  21],
#         [  3,  16,  24],
#         [ 95, 108, 116],
#         ...,
#         [  9,  13,  18],
#         [  9,  13,  18],
#         [  9,  13,  18]],
#
#        [[  1,  14,  22],
#         [  2,  15,  23],
#         [104, 117, 125],
#         ...,
#         [  7,  11,  16],
#         [  7,  11,  16],
#         [  7,  11,  16]],
#
#        [[  4,  17,  25],
#         [  1,  14,  22],
#         [105, 118, 126],
# ...

# %%
type(taj)
# Out:
# numpy.ndarray

# %%
plt.imshow(taj)

# %%
correct_color=cv2.cvtColor(taj,cv2.COLOR_BGR2RGB)   #changing it from bgr to rgb

# %%
plt.imshow(correct_color )

# %%
taj_gray=cv2.imread(r'E:\Imarticus\16.OPEN_CV\taj.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(taj_gray,cmap='gray')

# %%
correct_color_gray=cv2.cvtColor(taj_gray,cv2.COLOR_BGR2RGB) 
plt.imshow(correct_color_gray)  # we can't extract colors from gray image

# %%
train1=cv2.imread(r'E:\Imarticus\16.OPEN_CV\Train7.png') # PNG file makes our model slow

# %%
plt.imshow(train1)

# %%
correct_color1=cv2.cvtColor(train1,cv2.COLOR_BGR2RGB)#changing it from bgr to rgb
plt.imshow(correct_color1)

# %%
plt.imshow(cv2.flip(train1,1))

# %%
plt.imshow(cv2.flip(train1,0))

# %%
plt.imshow(cv2.flip(train1,-1))

# %%
original_train=(cv2.flip(train1,-1))

# %%
plt.imshow(cv2.flip(original_train,-1))

# %%
world=cv2.imread(r'E:\Imarticus\16.OPEN_CV\worldmap.png') # PNG file makes our model slow
plt.imshow(world)

# %%
correct_color_world=cv2.cvtColor(world,cv2.COLOR_BGR2RGB) 
plt.imshow(correct_color_world)

# %%
plt.figure(figsize=(10,10))
plt.imshow(correct_color_world)

# %%
plt.figure(figsize=(20,20))
plt.imshow((cv2.flip(correct_color_world,1)))

# %% [markdown]
# # Python image Library

# %%
from PIL import Image

# %%
pic1=Image.open(r'E:\Imarticus\16.OPEN_CV\Train7.png')

# %%
type(pic1)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
pic2=np.array(pic1)
plt.imshow(pic2)

# %%
pic2[:,:,0]    # Rmoving RGB channels
plt.imshow(pic2)

# %%
pic2[:,:,2]=0
plt.imshow(pic2)
